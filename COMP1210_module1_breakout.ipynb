# %% [markdown]
# <a href="https://colab.research.google.com/github/SIT-COMP-1210/module1-breakout-mekdes456/blob/main/COMP1210_module1_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Module1-Breakout-mekdes456.git
# Out:
# fatal: destination path 'Module1-Breakout-mekdes456' already exists and is not an empty directory.

# %% [markdown]
# **Instructions**
#
#
# *   Replace "{YourGitHubUser}" with your GitHub username
# *   Run the cell above to clone this .ipynb file to your git repository
#
#
# *   Once you are done completing the assignment below, click on "File" above, from the dropdown select "Save a copy in GitHub"
# *   Edit the commit message to reflect your latest change (e.g "Submitting Breakout Session Assignment")
#
#
# *   Commit your change
#
#
# *   Lastly, go to GitHub Classroom repository to confirm your file submission

# %% [markdown]
# **Practice Problems**

# %% [markdown]
# 1) What is wrong with this code?
#
#
# *   print("Hello World)

# %%
print("Hello World")

# %% [markdown]
# 2. Print all the values below
#
# *   Hello Word
# *   3
# *  2+2

# %%
print("Hello Word")
print(3)
print("2+2")

# %% [markdown]
# 3. Write a code that prints:
#
#
# *   Hello
#
#       Hello
#
#       Hello

# %%
print("Hello")
print("Hello")
print("Hello")

# %% [markdown]
# 4. Then combine it to 1 line:
#
#
# *   HelloHelloHello

# %%
print("Hello"*3)

# %% [markdown]
# 5. What will be printed when you run:
#
#
#
#   *   print("2" + "2")......22
#   *   print(2 + 2).........4
#
#   *   print("A")...........A
#   *   print("B")...........B
#
#
#   *   print("A" + "B").......AB
